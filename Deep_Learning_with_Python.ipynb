# %%
cd /content/drive/My\ Drive/Deep_Learning_With_Python
# Out:
# /content/drive/My Drive/Deep_Learning_With_Python

# %%
# !pip install kora
from kora import console
console.start()
# Out:
# ...
# Console URL: https://as.teleconsole.com/s/93d5a6a1e60e9f949277d806601927e75a381800

# %%
# !cp /content/drive/My\ Drive/Colab Notebooks/Deep_Learning_with_Python.ipynb /content/drive/My\ Drive/Deep_Learning_With_Python/
# Out:
# cp: cannot stat '/content/drive/My Drive/Colab': No such file or directory
# cp: cannot stat 'Notebooks/Deep_Learning_with_Python.ipynb': No such file or directory
